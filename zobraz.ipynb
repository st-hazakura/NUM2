# %%
x,y = [],[]
with open('fort.txt', 'r') as file:
    for line in file:
        a, b, c = map(float, line.split())
        x.append(a)
        y.append([b,c])

# %%
import matplotlib.pyplot as plt

plt.plot(x,y)
